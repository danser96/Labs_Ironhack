# %%
pip install mysql-connector-python
# Out:
# ...
#      |████████████████████████████████| 351 kB 1.3 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector
import pandas as pd
import pymysql

# %%
import sqlalchemy

# %%
conn = mysql.connector.connect(
  host="localhost",
  user="root",
  password="danielaversteeg1996",
    db= 'publications'
)

print(conn)

# %%
cursor = conn.cursor()
cursor.execute('show tables')

# %%
for table_name in cursor:
    print(table_name)
# Out:
# ('authors',)
# ('challenge1',)
# ('discounts',)
# ('employee',)
# ('jobs',)
# ('pub_info',)
# ('publishers',)
# ('roysched',)
# ('sales',)
# ('stores',)
# ('titleauthor',)
# ('titles',)

# %%
cursor = conn.cursor()

cursor.execute("show tables;")
 
myresult = cursor.fetchall()
 
for x in myresult:
    print(x)
# Out:
# ('authors',)
# ('challenge1',)
# ('discounts',)
# ('employee',)
# ('jobs',)
# ('pub_info',)
# ('publishers',)
# ('roysched',)
# ('sales',)
# ('stores',)
# ('titleauthor',)
# ('titles',)

# %%
df= pd.read_sql_query("SELECT * FROM publishers",conn)

print(df)
# Out:
#   pub_id               pub_name        city state  country
# 0   0736         New Moon Books      Boston    MA      USA
# 1   0877       Binnet & Hardley  Washington    DC      USA
# 2   1389   Algodata Infosystems    Berkeley    CA      USA
# 3   1622  Five Lakes Publishing     Chicago    IL      USA
# 4   1756      Ramona Publishers      Dallas    TX      USA
# 5   9901                  GGG&G    MÂnchen  None  Germany
# 6   9952         Scootney Books    New York    NY      USA
# 7   9999     Lucerne Publishing       Paris  None   France
# /Users/danser/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
df2= pd.read_sql_query("SELECT * FROM titles",conn)

print(df2)
# Out:
#    title_id                                              title          type  \
# 0    BU1032                The Busy Executive's Database Guide      business
# 1    BU1111  Cooking with Computers: Surreptitious Balance ...      business
# 2    BU2075                    You Can Combat Computer Stress!      business
# 3    BU7832                      Straight Talk About Computers      business
# 4    MC2222                  Silicon Valley Gastronomic Treats      mod_cook
# 5    MC3021                              The Gourmet Microwave      mod_cook
# 6    MC3026                 The Psychology of Computer Cooking     UNDECIDED
# 7    PC1035                           But Is It User Friendly?  popular_comp
# 8    PC8888                          Secrets of Silicon Valley  popular_comp
# 9    PC9999                                      Net Etiquette  popular_comp
# 10   PS1372  Computer Phobic AND Non-Phobic Individuals: Be...    psychology
# ...

# %% [markdown]
# # Introduction
# In this lab you will practice how to use the MySQL SELECT statement which will be extremely useful in your future work as a data analyst/scientist/engineer. You will use the publications database that we used in the Joins and Relationships lesson. In case you haven't had that database, here is the link to download the database file.
#
# You will create a solutions.sql file in the your-code directory to record your solutions to all challenges.
#
# # Challenge 1 - Who Have Published What At Where?
# In this challenge you will write a MySQL SELECT query that joins various tables to figure out what titles each author has published at which publishers. Your output should have at least the following columns:
#
# AUTHOR ID - the ID of the author LAST NAME - author last name FIRST NAME - author first name TITLE - name of the published title PUBLISHER - name of the publisher where the title was published

# %%
# %load_ext sql

# %%
# %sql mysql://root:danielaversteeg1996@localhost/publications

# %%
# %%sql
# SELECT table_name
# FROM information_schema.tables
# WHERE table_schema = 'publications';
# Out:
#  * mysql://root:***@localhost/publications
# 12 rows affected.
# [('authors',),
#  ('challenge1',),
#  ('discounts',),
#  ('employee',),
#  ('jobs',),
#  ('pub_info',),
#  ('publishers',),
#  ('roysched',),
#  ('sales',),
#  ('stores',),
#  ('titleauthor',),
#  ('titles',)]

# %%
# %%sql
#
# SELECT * from titleauthor
# Out:
#  * mysql://root:***@localhost/publications
# 25 rows affected.
# [('172-32-1176', 'PS3333', 1, 100),
#  ('213-46-8915', 'BU1032', 2, 40),
#  ('213-46-8915', 'BU2075', 1, 100),
#  ('238-95-7766', 'PC1035', 1, 100),
#  ('267-41-2394', 'BU1111', 2, 40),
#  ('267-41-2394', 'TC7777', 2, 30),
#  ('274-80-9391', 'BU7832', 1, 100),
#  ('409-56-7008', 'BU1032', 1, 60),
#  ('427-17-2319', 'PC8888', 1, 50),
#  ('472-27-2349', 'TC7777', 3, 30),
#  ('486-29-1786', 'PC9999', 1, 100),
#  ('486-29-1786', 'PS7777', 1, 100),
#  ('648-92-1872', 'TC4203', 1, 100),
#  ('672-71-3249', 'TC7777', 1, 40),
#  ('712-45-1867', 'MC2222', 1, 100),
#  ('722-51-5454', 'MC3021', 1, 75),
#  ('724-80-9391', 'BU1111', 1, 60),
#  ('724-80-9391', 'PS1372', 2, 25),
#  ('756-30-7391', 'PS1372', 1, 75),
#  ('807-91-6654', 'TC3218', 1, 100),
#  ('846-92-7186', 'PC8888', 2, 50),
#  ('899-46-2035', 'MC3021', 2, 25),
#  ('899-46-2035', 'PS2091', 2, 50),
#  ('998-72-3567', 'PS2091', 1, 50),
#  ('998-72-3567', 'PS2106', 1, 100)]

# %%
# %%sql
#
# SELECT * from titles
# Out:
#  * mysql://root:***@localhost/publications
# 18 rows affected.
# [('BU1032', "The Busy Executive's Database Guide", 'business', '1389', Decimal('19.9900'), Decimal('5000.0000'), 10, 4095, 'An overview of available database systems with emphasis on common business applications. Illustrated.', datetime.datetime(1991, 6, 12, 0, 0)),
#  ('BU1111', 'Cooking with Computers: Surreptitious Balance Sheets', 'business', '1389', Decimal('11.9500'), Decimal('5000.0000'), 10, 3876, 'Helpful hints on how to use your electronic resources to the best advantage.', datetime.datetime(1991, 6, 9, 0, 0)),
#  ('BU2075', 'You Can Combat Computer Stress!', 'business', '0736', Decimal('2.9900'), Decimal('10125.0000'), 24, 18722, 'The latest medical and psychological techniques for living with the electronic office. Easy-to-understand explanations.', datetime.datetime(1991, 6, 30, 0, 0)),
# ...

# %%
# %%sql
#
# SELECT * from authors
# Out:
#  * mysql://root:***@localhost/publications
# 23 rows affected.
# [('172-32-1176', 'White', 'Johnson', '408 496-7223', '10932 Bigge Rd.', 'Menlo Park', 'CA', '94025', 1),
#  ('213-46-8915', 'Green', 'Marjorie', '415 986-7020', '309 63rd St. #411', 'Oakland', 'CA', '94618', 1),
#  ('238-95-7766', 'Carson', 'Cheryl', '415 548-7723', '589 Darwin Ln.', 'Berkeley', 'CA', '94705', 1),
#  ('267-41-2394', "O'Leary", 'Michael', '408 286-2428', '22 Cleveland Av. #14', 'San Jose', 'CA', '95128', 1),
#  ('274-80-9391', 'Straight', 'Dean', '415 834-2919', '5420 College Av.', 'Oakland', 'CA', '94609', 1),
#  ('341-22-1782', 'Smith', 'Meander', '913 843-0462', '10 Mississippi Dr.', 'Lawrence', 'KS', '66044', 0),
#  ('409-56-7008', 'Bennet', 'Abraham', '415 658-9932', '6223 Bateman St.', 'Berkeley', 'CA', '94705', 1),
#  ('427-17-2319', 'Dull', 'Ann', '415 836-7128', '3410 Blonde St.', 'Palo Alto', 'CA', '94301', 1),
# ...

# %%
# %%sql
#
# SELECT * from publishers
# limit 5;
# Out:
#  * mysql://root:***@localhost/publications
# 5 rows affected.
# [('0736', 'New Moon Books', 'Boston', 'MA', 'USA'),
#  ('0877', 'Binnet & Hardley', 'Washington', 'DC', 'USA'),
#  ('1389', 'Algodata Infosystems', 'Berkeley', 'CA', 'USA'),
#  ('1622', 'Five Lakes Publishing', 'Chicago', 'IL', 'USA'),
#  ('1756', 'Ramona Publishers', 'Dallas', 'TX', 'USA')]

# %%
# %%sql
#
# SELECT authors.au_id, au_lname, au_fname, title, pub_name FROM authors
# JOIN titleauthor
# ON titleauthor.au_id = authors.au_id
# JOIN titles
# ON titleauthor.title_id = titles.title_id
# JOIN publishers
# ON titles.pub_id = publishers.pub_id;
# Out:
#  * mysql://root:***@localhost/publications
# 25 rows affected.
# [('213-46-8915', 'Green', 'Marjorie', "The Busy Executive's Database Guide", 'Algodata Infosystems'),
#  ('409-56-7008', 'Bennet', 'Abraham', "The Busy Executive's Database Guide", 'Algodata Infosystems'),
#  ('267-41-2394', "O'Leary", 'Michael', 'Cooking with Computers: Surreptitious Balance Sheets', 'Algodata Infosystems'),
#  ('724-80-9391', 'MacFeather', 'Stearns', 'Cooking with Computers: Surreptitious Balance Sheets', 'Algodata Infosystems'),
#  ('213-46-8915', 'Green', 'Marjorie', 'You Can Combat Computer Stress!', 'New Moon Books'),
#  ('274-80-9391', 'Straight', 'Dean', 'Straight Talk About Computers', 'Algodata Infosystems'),
#  ('712-45-1867', 'del Castillo', 'Innes', 'Silicon Valley Gastronomic Treats', 'Binnet & Hardley'),
#  ('722-51-5454', 'DeFrance', 'Michel', 'The Gourmet Microwave', 'Binnet & Hardley'),
#  ('899-46-2035', 'Ringer', 'Anne', 'The Gourmet Microwave', 'Binnet & Hardley'),
# ...

# %%
# %%sql
# SELECT * FROM challenge1
# Out:
#  * mysql://root:***@localhost/publications
# 25 rows affected.
# [('213-46-8915', 'Green', 'Marjorie', "The Busy Executive's Database Guide", 'Algodata Infosystems'),
#  ('409-56-7008', 'Bennet', 'Abraham', "The Busy Executive's Database Guide", 'Algodata Infosystems'),
#  ('267-41-2394', "O'Leary", 'Michael', 'Cooking with Computers: Surreptitious Balance Sheets', 'Algodata Infosystems'),
#  ('724-80-9391', 'MacFeather', 'Stearns', 'Cooking with Computers: Surreptitious Balance Sheets', 'Algodata Infosystems'),
#  ('213-46-8915', 'Green', 'Marjorie', 'You Can Combat Computer Stress!', 'New Moon Books'),
#  ('274-80-9391', 'Straight', 'Dean', 'Straight Talk About Computers', 'Algodata Infosystems'),
#  ('712-45-1867', 'del Castillo', 'Innes', 'Silicon Valley Gastronomic Treats', 'Binnet & Hardley'),
#  ('722-51-5454', 'DeFrance', 'Michel', 'The Gourmet Microwave', 'Binnet & Hardley'),
#  ('899-46-2035', 'Ringer', 'Anne', 'The Gourmet Microwave', 'Binnet & Hardley'),
# ...

# %% [markdown]
# # Challenge 2 - Who Have Published How Many At Where?
# Elevating from your solution in Challenge 1, query how many titles each author has published at each publisher. Your output should look something like below:

# %%
# %%sql
#
# SELECT pub_name, au_lname, au_fname, COUNT(title) as number_of_titles FROM authors
# JOIN titleauthor
# ON titleauthor.au_id = authors.au_id
# JOIN titles
# ON titleauthor.title_id = titles.title_id
# JOIN publishers
# ON titles.pub_id = publishers.pub_id
# GROUP BY pub_name, au_lname, au_fname;
# Out:
#  * mysql://root:***@localhost/publications
# 24 rows affected.
# [('Algodata Infosystems', 'Green', 'Marjorie', 1),
#  ('Algodata Infosystems', 'Bennet', 'Abraham', 1),
#  ('Algodata Infosystems', "O'Leary", 'Michael', 1),
#  ('Algodata Infosystems', 'MacFeather', 'Stearns', 1),
#  ('New Moon Books', 'Green', 'Marjorie', 1),
#  ('Algodata Infosystems', 'Straight', 'Dean', 1),
#  ('Binnet & Hardley', 'del Castillo', 'Innes', 1),
#  ('Binnet & Hardley', 'DeFrance', 'Michel', 1),
#  ('Binnet & Hardley', 'Ringer', 'Anne', 1),
#  ('Algodata Infosystems', 'Carson', 'Cheryl', 1),
#  ('Algodata Infosystems', 'Dull', 'Ann', 1),
#  ('Algodata Infosystems', 'Hunter', 'Sheryl', 1),
#  ('Algodata Infosystems', 'Locksley', 'Charlene', 1),
#  ('Binnet & Hardley', 'MacFeather', 'Stearns', 1),
#  ('Binnet & Hardley', 'Karsen', 'Livia', 1),
#  ('New Moon Books', 'Ringer', 'Anne', 1),
#  ('New Moon Books', 'Ringer', 'Albert', 2),
#  ('New Moon Books', 'White', 'Johnson', 1),
# ...

# %% [markdown]
# # Challenge 3 - Best Selling Authors
# Who are the top 3 authors who have sold the highest number of titles? Write a query to find out.

# %%
# %%sql
#
# SELECT * from sales
# Out:
#  * mysql://root:***@localhost/publications
# 21 rows affected.
# [('6380', '6871', datetime.datetime(1994, 9, 14, 0, 0), 5, 'Net 60', 'BU1032'),
#  ('6380', '722a', datetime.datetime(1994, 9, 13, 0, 0), 3, 'Net 60', 'PS2091'),
#  ('7066', 'A2976', datetime.datetime(1993, 5, 24, 0, 0), 50, 'Net 30', 'PC8888'),
#  ('7066', 'QA7442.3', datetime.datetime(1994, 9, 13, 0, 0), 75, 'ON invoice', 'PS2091'),
#  ('7067', 'D4482', datetime.datetime(1994, 9, 14, 0, 0), 10, 'Net 60', 'PS2091'),
#  ('7067', 'P2121', datetime.datetime(1992, 6, 15, 0, 0), 40, 'Net 30', 'TC3218'),
#  ('7067', 'P2121', datetime.datetime(1992, 6, 15, 0, 0), 20, 'Net 30', 'TC4203'),
#  ('7067', 'P2121', datetime.datetime(1992, 6, 15, 0, 0), 20, 'Net 30', 'TC7777'),
#  ('7131', 'N914008', datetime.datetime(1994, 9, 14, 0, 0), 20, 'Net 30', 'PS2091'),
#  ('7131', 'N914014', datetime.datetime(1994, 9, 14, 0, 0), 25, 'Net 30', 'MC3021'),
#  ('7131', 'P3087a', datetime.datetime(1993, 5, 29, 0, 0), 20, 'Net 60', 'PS1372'),
# ...

# %%
# %%sql
#
# SELECT * from authors
# Out:
#  * mysql://root:***@localhost/publications
# 23 rows affected.
# [('172-32-1176', 'White', 'Johnson', '408 496-7223', '10932 Bigge Rd.', 'Menlo Park', 'CA', '94025', 1),
#  ('213-46-8915', 'Green', 'Marjorie', '415 986-7020', '309 63rd St. #411', 'Oakland', 'CA', '94618', 1),
#  ('238-95-7766', 'Carson', 'Cheryl', '415 548-7723', '589 Darwin Ln.', 'Berkeley', 'CA', '94705', 1),
#  ('267-41-2394', "O'Leary", 'Michael', '408 286-2428', '22 Cleveland Av. #14', 'San Jose', 'CA', '95128', 1),
#  ('274-80-9391', 'Straight', 'Dean', '415 834-2919', '5420 College Av.', 'Oakland', 'CA', '94609', 1),
#  ('341-22-1782', 'Smith', 'Meander', '913 843-0462', '10 Mississippi Dr.', 'Lawrence', 'KS', '66044', 0),
#  ('409-56-7008', 'Bennet', 'Abraham', '415 658-9932', '6223 Bateman St.', 'Berkeley', 'CA', '94705', 1),
#  ('427-17-2319', 'Dull', 'Ann', '415 836-7128', '3410 Blonde St.', 'Palo Alto', 'CA', '94301', 1),
# ...

# %%
# %%sql
#
# SELECT authors.au_id, au_lname, au_fname, SUM(qty) AS units_sold FROM authors
# JOIN titleauthor
# ON titleauthor.au_id = authors.au_id
# JOIN sales
# ON sales.title_id = titleauthor.title_id
# GROUP BY authors.au_id, au_lname, au_fname
# ORDER BY units_sold desc
# limit 5;
# Out:
#  * mysql://root:***@localhost/publications
# 5 rows affected.
# [('899-46-2035', 'Ringer', 'Anne', Decimal('148')),
#  ('998-72-3567', 'Ringer', 'Albert', Decimal('133')),
#  ('213-46-8915', 'Green', 'Marjorie', Decimal('50')),
#  ('427-17-2319', 'Dull', 'Ann', Decimal('50')),
#  ('846-92-7186', 'Hunter', 'Sheryl', Decimal('50'))]

# %% [markdown]
# # Challenge 4 - Best Selling Authors Ranking
# Now modify your solution in Challenge 3 so that the output will display all 23 authors instead of the top 3. Note that the authors who have sold 0 titles should also appear in your output (ideally display 0 instead of NULL as the TOTAL). Also order your results based on TOTAL from high to low.

# %%
# %%sql
#
# SELECT authors.au_id, au_lname, au_fname, SUM(qty) AS units_sold FROM authors
# RIGHT JOIN titleauthor
# ON titleauthor.au_id = authors.au_id
# RIGHT JOIN sales
# ON sales.title_id = titleauthor.title_id
# GROUP BY authors.au_id, au_lname, au_fname
#
# UNION
#
# SELECT authors.au_id, au_lname, au_fname, SUM(qty) AS units_sold FROM authors
# LEFT JOIN titleauthor
# ON titleauthor.au_id = authors.au_id
# LEFT JOIN sales
# ON sales.title_id = titleauthor.title_id
# GROUP BY authors.au_id, au_lname, au_fname;
# Out:
#  * mysql://root:***@localhost/publications
# 23 rows affected.
# [('213-46-8915', 'Green', 'Marjorie', Decimal('50')),
#  ('409-56-7008', 'Bennet', 'Abraham', Decimal('15')),
#  ('899-46-2035', 'Ringer', 'Anne', Decimal('148')),
#  ('998-72-3567', 'Ringer', 'Albert', Decimal('133')),
#  ('427-17-2319', 'Dull', 'Ann', Decimal('50')),
#  ('846-92-7186', 'Hunter', 'Sheryl', Decimal('50')),
#  ('807-91-6654', 'Panteley', 'Sylvia', Decimal('40')),
#  ('648-92-1872', 'Blotchet-Halls', 'Reginald', Decimal('20')),
#  ('267-41-2394', "O'Leary", 'Michael', Decimal('45')),
#  ('472-27-2349', 'Gringlesby', 'Burt', Decimal('20')),
#  ('672-71-3249', 'Yokomoto', 'Akiko', Decimal('20')),
#  ('722-51-5454', 'DeFrance', 'Michel', Decimal('40')),
#  ('724-80-9391', 'MacFeather', 'Stearns', Decimal('45')),
#  ('756-30-7391', 'Karsen', 'Livia', Decimal('20')),
#  ('172-32-1176', 'White', 'Johnson', Decimal('15')),
#  ('486-29-1786', 'Locksley', 'Charlene', Decimal('25')),
# ...
